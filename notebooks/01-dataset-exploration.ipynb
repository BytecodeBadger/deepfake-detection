# %% [markdown]
# # Explore deepfake dataset

# %%
import kagglehub
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
path = kagglehub.dataset_download("manjilkarki/deepfake-and-real-images")

print("Path to dataset files:", path)
